# %% [markdown]
# # ***Tabla Icfes 2019-2.***

# %%
# %load_ext autoreload
# %autoreload 2
from google.colab import drive
drive.mount('/content/drive')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Ucentral Maestría/Año_2023/Funda_Esta_Analítica_2023-I_GR09/
# Out:
# /content/drive/MyDrive/Ucentral Maestría/Año_2023/Funda_Esta_Analítica_2023-I_GR09

# %%
#cd /content/drive/MyDrive/Ucentral Maestría/Fundamentos_2022-II/Tarea_1

# %%
# !ls Tarea_1
# Out:
# Grupos_Tarea1.gsheet  Saber_11_2019-2.csv  tablas_dept	tablas_T1.ipynb

# %%
import pandas as pd
import warnings

##
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', 10) 
#pd.set_option('display.width', 78) 
#pd.set_option('precision', 3)

# %% [markdown]
# Los datos son obtenidos de [acá](https://www.datos.gov.co/Educaci-n/PUNTAJE-ICFES-POR-DEPARTAMENTOS/x9vi-iv8c)

# %%
df = pd.read_csv('Tarea_1/Saber_11_2019-2.csv',)

# %%
df.shape
# Out:
# (546212, 82)

# %%
df.head()
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                 TI          COLOMBIA           M  06/28/2003 12:00:00 AM
# 2                 TI          COLOMBIA           M  06/02/2001 12:00:00 AM
# 3                 TI          COLOMBIA           M  04/26/2002 12:00:00 AM
# 4                 TI          COLOMBIA           M  02/05/2002 12:00:00 AM
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# 2    20194  SB11201940255017      ESTUDIANTE              No         COLOMBIA
# 3    20194  SB11201940154799      ESTUDIANTE              Si         COLOMBIA
# 4    20194  SB11201940280831      ESTUDIANTE              No         COLOMBIA
#
# ...

# %%
vars = ['ESTU_DEPTO_RESIDE','FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE', 
        'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR', 'FAMI_COMELECHEDERIVADOS', 'FAMI_COMECARNEPESCADOHUEVO', 
        'FAMI_COMECEREALFRUTOSLEGUMBRE', 'ESTU_DEDICACIONINTERNET', 'COLE_GENERO', 'COLE_NATURALEZA', 'COLE_CALENDARIO', 
        'COLE_CARACTER', 'COLE_JORNADA', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_SOCIALES_CIUDADANAS', 
        'PUNT_INGLES', 'PUNT_GLOBAL', 'ESTU_FECHANACIMIENTO','ESTU_GENERO', 'ESTU_GENERACION-E' ]
df_stud = df[vars]
df_stud.head()
# Out:
#   ESTU_DEPTO_RESIDE FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR  \
# 0         MAGDALENA            Estrato 3              5 a 6
# 1            BOGOTÁ            Estrato 3            9 o más
# 2           BOLIVAR            Estrato 1              5 a 6
# 3            BOGOTÁ            Estrato 3              3 a 4
# 4            BOGOTÁ            Estrato 3              3 a 4
#
#                   FAMI_EDUCACIONPADRE                   FAMI_EDUCACIONMADRE  \
# 0      Educación profesional completa    Secundaria (Bachillerato) completa
# 1      Técnica o tecnológica completa        Técnica o tecnológica completa
# 2  Secundaria (Bachillerato) completa    Secundaria (Bachillerato) completa
# 3                 Primaria incompleta    Secundaria (Bachillerato) completa
# 4  Secundaria (Bachillerato) completa  Secundaria (Bachillerato) incompleta
#
#   FAMI_TIENEINTERNET FAMI_TIENECOMPUTADOR      FAMI_COMELECHEDERIVADOS  \
# 0                 Si                   No       1 o 2 veces por semana
# ...

# %%
print(len(df_stud['ESTU_DEPTO_RESIDE'].dropna().unique()))
df_stud['ESTU_DEPTO_RESIDE'].dropna().unique()
# Out:
# 34
# array(['MAGDALENA', 'BOGOTÁ', 'BOLIVAR', 'ATLANTICO', 'VALLE',
#        'SANTANDER', 'CUNDINAMARCA', 'SUCRE', 'ANTIOQUIA', 'CESAR',
#        'BOYACA', 'HUILA', 'CASANARE', 'CAUCA', 'CORDOBA',
#        'NORTE SANTANDER', 'QUINDIO', 'ARAUCA', 'META', 'CHOCO',
#        'LA GUAJIRA', 'SAN ANDRES', 'TOLIMA', 'NARIÑO', 'CALDAS', 'VAUPES',
#        'RISARALDA', 'PUTUMAYO', 'VICHADA', 'CAQUETA', 'AMAZONAS',
#        'GUAVIARE', 'GUAINIA', 'EXTRANJERO'], dtype=object)

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Ucentral Maestría/Año_2023/Funda_Esta_Analítica_2023-I_GR09

# %%
for dept in df_stud['ESTU_DEPTO_RESIDE'].dropna().unique():
    df_stud_temp = df_stud[df_stud['ESTU_DEPTO_RESIDE'] == dept]
    df_stud_temp.to_csv('Tarea_1/tablas_dept/'+ dept + '.csv',index=False)

# %%
df_huila = pd.read_csv('Tarea_1/tablas_dept/HUILA.csv')
df_huila
# Out:
#       ESTU_DEPTO_RESIDE FAMI_ESTRATOVIVIENDA FAMI_PERSONASHOGAR  \
# 0                 HUILA            Estrato 2              3 a 4
# 1                 HUILA            Estrato 2              3 a 4
# 2                 HUILA            Estrato 1              3 a 4
# 3                 HUILA            Estrato 2              3 a 4
# 4                 HUILA            Estrato 1              3 a 4
# ...                 ...                  ...                ...
# 14083             HUILA            Estrato 1              5 a 6
# 14084             HUILA            Estrato 1              3 a 4
# 14085             HUILA            Estrato 2              5 a 6
# 14086             HUILA            Estrato 2              5 a 6
# 14087             HUILA            Estrato 3              3 a 4
#
#                         FAMI_EDUCACIONPADRE  \
# 0                         Primaria completa
# 1                                   No sabe
# 2                         Primaria completa
# ...
